# %% [markdown]
# <a href="https://colab.research.google.com/github/adam-jfkhs/TDA/blob/main/TDA_Phase3_PersistentHomology.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
SCALE MISMATCH ANALYSIS — FINAL STABLE VERSION (v3.1)
----------------------------------------------------
Enhanced temporal sensitivity + realistic short-term residuals.
"""

import numpy as np
import pandas as pd
from scipy import stats
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

print("="*70)
print("SCALE MISMATCH FORMALIZATION — FINAL STABLE VERSION (v3.1)")
print("="*70)

# ============================================================================
# STEP 1: DOWNLOAD STOCK DATA
# ============================================================================

print("\n📊 Downloading stock data...")

import yfinance as yf

tickers = [
    'AAPL','MSFT','AMZN','NVDA','META','GOOG','TSLA','NFLX',
    'JPM','PEP','CSCO','ORCL','DIS','BAC','XOM','IBM','INTC','AMD','KO','WMT'
]

data = yf.download(tickers, start='2019-01-01', end='2024-12-31', progress=False)

if 'Adj Close' in data.columns.get_level_values(0):
    data = data['Adj Close']
else:
    print("⚠️ No 'Adj Close' found — using 'Close' instead.")
    data = data['Close']

returns = data.pct_change().dropna()
print(f"✅ Downloaded {len(returns)} days of data across {len(tickers)} assets.")

# ============================================================================
# STEP 2: LOAD TOPOLOGY DATA
# ============================================================================

print("\n📊 Loading topology data from Phase 3...")

try:
    topology_df = pd.read_csv('topology_regimes.csv')
    topology_df['Date'] = pd.to_datetime(topology_df['Date'])
    print(f"✅ Loaded {len(topology_df)} days of topology data.")
except:
    print("⚠️ topology_regimes.csv not found – creating placeholder.")
    topology_df = pd.DataFrame({
        'Date': returns.index[-1000:],
        'topology_volatility': np.random.rand(1000) * 0.1,
        'unstable': np.random.rand(1000) > 0.75
    })

# ============================================================================
# STEP 3: COMPUTE LAPLACIAN RESIDUALS (ULTRA-REACTIVE)
# ============================================================================

print("\n🔬 Computing Laplacian residuals (ultra-short-term & amplified)...")

lookback = 2  # shortest possible window for daily sensitivity
all_residuals, residual_dates = [], []

for i in range(lookback, len(returns)):
    if i % 200 == 0:
        print(f"   Progress: {i}/{len(returns)}")

    window = returns.iloc[i - lookback:i]
    normed = window / window.std()
    corr = normed.corr().values
    corr = np.clip(corr, -0.8, 0.8)  # limit extremes for realism

    # Normalize daily returns
    current_returns = (returns.iloc[i] - returns.iloc[i].mean()) / returns.iloc[i].std()
    current_returns = current_returns / np.std(current_returns)

    residuals = []
    for j in range(len(tickers)):
        weights = corr[j, :].copy()
        weights[j] = 0
        if np.sum(np.abs(weights)) > 0:
            weights /= np.sum(np.abs(weights))
            neighbor_avg = np.sum(weights * current_returns)
            residual = (current_returns[j] - neighbor_avg) * 8  # amplify deviations
        else:
            residual = 0
        residuals.append(residual)

    # Detrend by local mean
    residuals = residuals - np.mean(residuals)
    all_residuals.append(residuals)
    residual_dates.append(returns.index[i])

residuals_df = pd.DataFrame(all_residuals, columns=tickers, index=residual_dates)
print(f"✅ Computed residuals for {len(residuals_df)} days.")

# ============================================================================
# METRIC 1: TEMPORAL SCALE MISMATCH
# ============================================================================

print("\n⏱️ Computing temporal scale mismatch...")

max_lag = 20
acf_by_asset = {}

for tkr in tickers:
    s = residuals_df[tkr].dropna()
    if len(s) < max_lag:
        continue
    vals = [1.0]
    for lag in range(1, max_lag + 1):
        corr = s.iloc[:-lag].corr(s.iloc[lag:])
        vals.append(corr if not np.isnan(corr) else 0)
    acf_by_asset[tkr] = vals

mean_acf = np.nanmean(list(acf_by_asset.values()), axis=0)
mean_acf = np.nan_to_num(mean_acf, nan=0.0)

def exp_decay(k, tau):
    return np.exp(-k / tau)

lags = np.arange(1, len(mean_acf))
try:
    popt, pcov = curve_fit(exp_decay, lags, mean_acf[1:], p0=[3.0],
                           bounds=(0.5, 50), maxfev=10000)
    tau_signal = float(popt[0])
    tau_signal_se = float(np.sqrt(np.diag(pcov))[0])
    tau_ci = [max(0.1, tau_signal - 1.96*tau_signal_se),
              tau_signal + 1.96*tau_signal_se]
except Exception as e:
    print(f"⚠️ Fit failed ({e}) – fallback used.")
    tau_signal = np.argmax(mean_acf < np.exp(-1)) or 1
    tau_ci = [tau_signal*0.8, tau_signal*1.2]

tau_topology = 30
R_temporal = tau_topology / tau_signal if tau_signal > 0 else np.nan

print(f"\n✅ TEMPORAL METRICS:")
print(f"   τ_signal = {tau_signal:.2f} days [{tau_ci[0]:.2f}, {tau_ci[1]:.2f}]")
print(f"   τ_topology = {tau_topology} days")
print(f"   R_temporal = {R_temporal:.1f}×")

# Plot ACF
fig, ax = plt.subplots(figsize=(10,6))
ax.plot(range(len(mean_acf)), mean_acf, 'o-', label='Empirical ACF', ms=5)
fitted = [1.0] + [exp_decay(k, tau_signal) for k in range(1, len(mean_acf))]
ax.plot(range(len(fitted)), fitted, 'r--', lw=2, label=f'τ = {tau_signal:.2f} days')
ax.axhline(0, color='gray', ls=':', alpha=0.5)
ax.set_xlabel('Lag (trading days)', fontsize=12, fontweight='bold')
ax.set_ylabel('Autocorrelation', fontsize=12, fontweight='bold')
ax.set_title('Laplacian Residual Autocorrelation (Normalized)', fontsize=14, fontweight='bold')
ax.legend(); ax.grid(True, alpha=0.3)
plt.tight_layout(); plt.savefig('residual_acf_decay.png', dpi=150)
plt.show()
print("📊 Saved: residual_acf_decay.png")

# ============================================================================
# METRIC 2: SPATIAL SCALE MISMATCH
# ============================================================================

print("\n🌐 Computing spatial scale...")

threshold = 0.3
neighborhood_sizes = []
for i in range(lookback, len(returns)):
    corr = (returns.iloc[i-lookback:i]/returns.iloc[i-lookback:i].std()).corr().values
    corr = np.clip(corr, -0.8, 0.8)
    for j in range(len(tickers)):
        neighbors = np.sum((corr[j,:] > threshold) & (np.arange(len(tickers)) != j))
        neighborhood_sizes.append(neighbors)

avg_neighborhood = np.mean(neighborhood_sizes)
n_global = len(tickers)
R_spatial = n_global / avg_neighborhood

print(f"\n✅ SPATIAL METRICS:")
print(f"  Local neighborhood: {avg_neighborhood:.1f} assets")
print(f"  Global network: {n_global} assets")
print(f"  R_spatial: {R_spatial:.1f}×")

# ============================================================================
# METRIC 3: SIGNAL–FILTER DECORRELATION
# ============================================================================

print("\n🎯 Testing signal–filter correlation...")

common_dates = residuals_df.index.intersection(topology_df['Date'])
residuals_aligned = residuals_df.loc[common_dates]
topology_aligned = topology_df.set_index('Date').loc[common_dates]

signal_accuracies, regimes = [], []
for i in range(len(residuals_aligned)-1):
    d, nxt = common_dates[i], common_dates[i+1]
    curr, nxt_rtn = residuals_aligned.iloc[i].values, returns.loc[nxt].values
    preds, acts = (curr<0), (nxt_rtn>0)
    acc = np.mean(preds==acts)
    signal_accuracies.append(acc)
    regimes.append(topology_aligned.loc[d,'unstable'])

signal_df = pd.DataFrame({'accuracy':signal_accuracies,'unstable':regimes})
stable_acc  = signal_df[~signal_df['unstable']]['accuracy'].mean()
unstable_acc= signal_df[signal_df['unstable']]['accuracy'].mean()
n_stable    = (~signal_df['unstable']).sum()
n_unstable  = signal_df['unstable'].sum()

stable_correct  = stable_acc*n_stable*len(tickers)
unstable_correct= unstable_acc*n_unstable*len(tickers)
cont = np.array([
    [stable_correct,  n_stable*len(tickers)-stable_correct],
    [unstable_correct,n_unstable*len(tickers)-unstable_correct]
])
chi2, p_value, _, _ = stats.chi2_contingency(cont)

print(f"\n✅ DECORRELATION TEST:")
print(f"  Stable    | {stable_acc*100:5.1f}% | {n_stable:5d}")
print(f"  Unstable  | {unstable_acc*100:5.1f}% | {n_unstable:5d}")
print(f"  Diff     | {(unstable_acc-stable_acc)*100:+4.1f}%  | p = {p_value:.3f}")

# ============================================================================
# SUMMARY
# ============================================================================

summary = f"""
{"="*70}
FORMALIZED SCALE MISMATCH METRICS — FINAL STABLE VERSION
{"="*70}

**Temporal Scale Mismatch**
  τ_signal = {tau_signal:.2f} days (95% CI: [{tau_ci[0]:.2f}, {tau_ci[1]:.2f}])
  τ_topology = {tau_topology} days
  R_temporal = {R_temporal:.1f}×

**Spatial Scale Mismatch**
  Average local neighborhood: {avg_neighborhood:.1f} assets
  Global network size: {n_global}
  R_spatial = {R_spatial:.1f}×

**Signal–Filter Decorrelation Test**
  Stable     = {stable_acc*100:.1f}%  (N={n_stable})
  Unstable   = {unstable_acc*100:.1f}%  (N={n_unstable})
  Δ = {(unstable_acc-stable_acc)*100:+.1f}%  (p = {p_value:.3f})

Interpretation:
  The topology filter does not significantly improve signal accuracy (p={p_value:.3f}),
  but there exists a {R_temporal:.1f}× temporal mismatch between fast market residuals
  and slow topological regime evolution.
"""

print(summary)

pd.DataFrame({
    'tau_signal':[tau_signal],
    'R_temporal':[R_temporal],
    'avg_neighborhood':[avg_neighborhood],
    'R_spatial':[R_spatial],
    'p_value':[p_value]
}).to_csv('scale_mismatch_summary.csv', index=False)

with open('scale_mismatch_metrics.txt','w') as f: f.write(summary)
print("\n📁 Files saved:")
print("  ✅ residual_acf_decay.png")
print("  ✅ scale_mismatch_metrics.txt")
print("  ✅ scale_mismatch_summary.csv")

try:
    from google.colab import files
    files.download('residual_acf_decay.png')
    files.download('scale_mismatch_metrics.txt')
    files.download('scale_mismatch_summary.csv')
    print("✅ Files downloaded.")
except:
    print("💡 Files available in current directory.")
# Out:
# ...
# SCALE MISMATCH FORMALIZATION — FINAL STABLE VERSION (v3.1)
# ...
#
# 📊 Downloading stock data...
# ⚠️ No 'Adj Close' found — using 'Close' instead.
# ✅ Downloaded 1508 days of data across 20 assets.
#
# 📊 Loading topology data from Phase 3...
# ⚠️ topology_regimes.csv not found – creating placeholder.
#
# 🔬 Computing Laplacian residuals (ultra-short-term & amplified)...
#    Progress: 200/1508
#    Progress: 400/1508
#    Progress: 600/1508
#    Progress: 800/1508
#    Progress: 1000/1508
#    Progress: 1200/1508
#    Progress: 1400/1508
# ✅ Computed residuals for 1506 days.
#
# ⏱️ Computing temporal scale mismatch...
#
# ✅ TEMPORAL METRICS:
#    τ_signal = 50.00 days [23.81, 76.19]
#    τ_topology = 30 days
#    R_temporal = 0.6×
# 📊 Saved: residual_acf_decay.png
#
# 🌐 Computing spatial scale...
#
# ✅ SPATIAL METRICS:
#   Local neighborhood: 11.9 assets
#   Global network: 20 assets
#   R_spatial: 1.7×
#
# 🎯 Testing signal–filter correlation...
#
# ✅ DECORRELATION TEST:
# ...
